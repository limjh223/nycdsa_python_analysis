# %%
import pandas as pd
import numpy as np

weather = pd.read_csv('weather_data_24hr.csv')

# %%
weather
# Out:
#       loc_id        date  maxtempC  maxtempF  mintempC  mintempF  avgtempC  \
# 0          1  2008-07-01        27        80        20        67        23
# 1          1  2008-07-02        27        81        19        66        23
# 2          1  2008-07-03        29        83        20        67        24
# 3          1  2008-07-04        25        76        21        69        22
# 4          1  2008-07-05        26        79        20        68        23
# ...      ...         ...       ...       ...       ...       ...       ...
# 4846       1  2021-10-07        24        74        19        65        21
# 4847       1  2021-10-08        28        83        19        66        22
# 4848       1  2021-10-09        21        69        18        64        19
# 4849       1  2021-10-10        21        70        18        64        19
# 4850       1  2021-10-11        24        74        18        64        20
#
#       avgtempF  totalprecipMM  totalprecipIn  ...  WindGustKmph  FeelsLikeC  \
# 0           74            3.5           0.14  ...            14          25
# 1           73            0.4           0.02  ...            18          24
# 2           75            0.0           0.00  ...            25          25
# 3           71            6.1           0.24  ...             7          22
# 4           73           12.8           0.50  ...             8          24
# ...        ...            ...            ...  ...           ...         ...
# 4846        69            0.0           0.00  ...            10          21
# 4847        72            0.0           0.00  ...            10          23
# 4848        66            0.2           0.01  ...            26          19
# 4849        67            0.0           0.00  ...            21          19
# 4850        68            0.0           0.00  ...            25          20
#
#       FeelsLikeF  uvIndex   sunrise    sunset  moonrise   moonset  \
# 0             77        5  05:28 AM  08:30 PM  03:23 AM  07:36 PM
# 1             75        6  05:28 AM  08:30 PM  04:28 AM  08:36 PM
# 2             76        6  05:29 AM  08:30 PM  05:44 AM  09:23 PM
# 3             71        5  05:30 AM  08:29 PM  07:03 AM  10:00 PM
# 4             75        6  05:30 AM  08:29 PM  08:20 AM  10:30 PM
# ...          ...      ...       ...       ...       ...       ...
# 4846          69        5  06:58 AM  06:27 PM  08:10 AM  07:24 PM
# 4847          73        6  06:59 AM  06:25 PM  09:27 AM  07:56 PM
# 4848          66        4  07:00 AM  06:23 PM  10:44 AM  08:34 PM
# 4849          67        4  07:01 AM  06:22 PM  12:01 PM  09:20 PM
# 4850          68        5  07:02 AM  06:20 PM  01:13 PM  10:14 PM
#
#            moon_phase  moon_illumination
# 0      Waning Gibbous               89.7
# 1      Waning Gibbous               82.8
# 2      Waning Gibbous               75.9
# 3        Last Quarter               69.0
# 4        Last Quarter               62.1
# ...               ...                ...
# 4846  Waxing Crescent               13.8
# 4847  Waxing Crescent               20.7
# 4848    First Quarter               27.6
# 4849    First Quarter               34.5
# 4850    First Quarter               41.4
#
# [4851 rows x 41 columns]

# %%
weather.drop('loc_id', axis = 1, inplace = True)

# %%
weather
# Out:
#             date  maxtempC  maxtempF  mintempC  mintempF  avgtempC  avgtempF  \
# 0     2008-07-01        27        80        20        67        23        74
# 1     2008-07-02        27        81        19        66        23        73
# 2     2008-07-03        29        83        20        67        24        75
# 3     2008-07-04        25        76        21        69        22        71
# 4     2008-07-05        26        79        20        68        23        73
# ...          ...       ...       ...       ...       ...       ...       ...
# 4846  2021-10-07        24        74        19        65        21        69
# 4847  2021-10-08        28        83        19        66        22        72
# 4848  2021-10-09        21        69        18        64        19        66
# 4849  2021-10-10        21        70        18        64        19        67
# 4850  2021-10-11        24        74        18        64        20        68
#
#       totalprecipMM  totalprecipIn  windspeedMiles  ...  WindGustKmph  \
# 0               3.5           0.14               5  ...            14
# 1               0.4           0.02               7  ...            18
# 2               0.0           0.00               9  ...            25
# 3               6.1           0.24               3  ...             7
# 4              12.8           0.50               3  ...             8
# ...             ...            ...             ...  ...           ...
# 4846            0.0           0.00               5  ...            10
# 4847            0.0           0.00               5  ...            10
# 4848            0.2           0.01              13  ...            26
# 4849            0.0           0.00              10  ...            21
# 4850            0.0           0.00              12  ...            25
#
#       FeelsLikeC  FeelsLikeF uvIndex   sunrise    sunset  moonrise   moonset  \
# 0             25          77       5  05:28 AM  08:30 PM  03:23 AM  07:36 PM
# 1             24          75       6  05:28 AM  08:30 PM  04:28 AM  08:36 PM
# 2             25          76       6  05:29 AM  08:30 PM  05:44 AM  09:23 PM
# 3             22          71       5  05:30 AM  08:29 PM  07:03 AM  10:00 PM
# 4             24          75       6  05:30 AM  08:29 PM  08:20 AM  10:30 PM
# ...          ...         ...     ...       ...       ...       ...       ...
# 4846          21          69       5  06:58 AM  06:27 PM  08:10 AM  07:24 PM
# 4847          23          73       6  06:59 AM  06:25 PM  09:27 AM  07:56 PM
# 4848          19          66       4  07:00 AM  06:23 PM  10:44 AM  08:34 PM
# 4849          19          67       4  07:01 AM  06:22 PM  12:01 PM  09:20 PM
# 4850          20          68       5  07:02 AM  06:20 PM  01:13 PM  10:14 PM
#
#            moon_phase  moon_illumination
# 0      Waning Gibbous               89.7
# 1      Waning Gibbous               82.8
# 2      Waning Gibbous               75.9
# 3        Last Quarter               69.0
# 4        Last Quarter               62.1
# ...               ...                ...
# 4846  Waxing Crescent               13.8
# 4847  Waxing Crescent               20.7
# 4848    First Quarter               27.6
# 4849    First Quarter               34.5
# 4850    First Quarter               41.4
#
# [4851 rows x 40 columns]

# %%
weather.drop(['maxtempC', 'mintempC','avgtempC'], axis = 1, inplace = True)

# %%
weather
# Out:
#             date  maxtempF  mintempF  avgtempF  totalprecipMM  totalprecipIn  \
# 0     2008-07-01        80        67        74            3.5           0.14
# 1     2008-07-02        81        66        73            0.4           0.02
# 2     2008-07-03        83        67        75            0.0           0.00
# 3     2008-07-04        76        69        71            6.1           0.24
# 4     2008-07-05        79        68        73           12.8           0.50
# ...          ...       ...       ...       ...            ...            ...
# 4846  2021-10-07        74        65        69            0.0           0.00
# 4847  2021-10-08        83        66        72            0.0           0.00
# 4848  2021-10-09        69        64        66            0.2           0.01
# 4849  2021-10-10        70        64        67            0.0           0.00
# 4850  2021-10-11        74        64        68            0.0           0.00
#
#       windspeedMiles  windspeedKmph  sunhour  winddirdegree  ... WindGustKmph  \
# 0                  5              8     11.2            195  ...           14
# 1                  7             11     11.2            261  ...           18
# 2                  9             15     11.2            219  ...           25
# 3                  3              5     11.2            195  ...            7
# 4                  3              5     11.2            141  ...            8
# ...              ...            ...      ...            ...  ...          ...
# 4846               5              7      8.5            230  ...           10
# 4847               5              7     11.2            241  ...           10
# 4848              13             21      7.0             81  ...           26
# 4849              10             16      7.0             86  ...           21
# 4850              12             19      7.0             50  ...           25
#
#       FeelsLikeC FeelsLikeF uvIndex   sunrise    sunset  moonrise   moonset  \
# 0             25         77       5  05:28 AM  08:30 PM  03:23 AM  07:36 PM
# 1             24         75       6  05:28 AM  08:30 PM  04:28 AM  08:36 PM
# 2             25         76       6  05:29 AM  08:30 PM  05:44 AM  09:23 PM
# 3             22         71       5  05:30 AM  08:29 PM  07:03 AM  10:00 PM
# 4             24         75       6  05:30 AM  08:29 PM  08:20 AM  10:30 PM
# ...          ...        ...     ...       ...       ...       ...       ...
# 4846          21         69       5  06:58 AM  06:27 PM  08:10 AM  07:24 PM
# 4847          23         73       6  06:59 AM  06:25 PM  09:27 AM  07:56 PM
# 4848          19         66       4  07:00 AM  06:23 PM  10:44 AM  08:34 PM
# 4849          19         67       4  07:01 AM  06:22 PM  12:01 PM  09:20 PM
# 4850          20         68       5  07:02 AM  06:20 PM  01:13 PM  10:14 PM
#
#            moon_phase  moon_illumination
# 0      Waning Gibbous               89.7
# 1      Waning Gibbous               82.8
# 2      Waning Gibbous               75.9
# 3        Last Quarter               69.0
# 4        Last Quarter               62.1
# ...               ...                ...
# 4846  Waxing Crescent               13.8
# 4847  Waxing Crescent               20.7
# 4848    First Quarter               27.6
# 4849    First Quarter               34.5
# 4850    First Quarter               41.4
#
# [4851 rows x 37 columns]

# %%
weather.drop(['totalprecipMM', 
              'windspeedKmph',
              'sunhour', 
              'winddirdegree',
              'moonrise',
              'moonset',
              'moon_phase',
              'moon_illumination',], axis = 1, inplace = True)

# %%
weather
# Out:
#             date  maxtempF  mintempF  avgtempF  totalprecipIn  windspeedMiles  \
# 0     2008-07-01        80        67        74           0.14               5
# 1     2008-07-02        81        66        73           0.02               7
# 2     2008-07-03        83        67        75           0.00               9
# 3     2008-07-04        76        69        71           0.24               3
# 4     2008-07-05        79        68        73           0.50               3
# ...          ...       ...       ...       ...            ...             ...
# 4846  2021-10-07        74        65        69           0.00               5
# 4847  2021-10-08        83        66        72           0.00               5
# 4848  2021-10-09        69        64        66           0.01              13
# 4849  2021-10-10        70        64        67           0.00              10
# 4850  2021-10-11        74        64        68           0.00              12
#
#      winddir16point  weatherCode  \
# 0               SSW          176
# 1                 W          113
# 2                SW          113
# 3               SSW          353
# 4                SE          113
# ...             ...          ...
# 4846             SW          119
# 4847            WSW          116
# 4848              E          122
# 4849              E          119
# 4850             NE          122
#
#                                          weatherIconUrl           weatherDesc  \
# 0     https://cdn.worldweatheronline.com/images/wsym...  Patchy rain possible
# 1     https://cdn.worldweatheronline.com/images/wsym...                 Sunny
# 2     https://cdn.worldweatheronline.com/images/wsym...                 Sunny
# 3     https://cdn.worldweatheronline.com/images/wsym...     Light rain shower
# 4     https://cdn.worldweatheronline.com/images/wsym...                 Sunny
# ...                                                 ...                   ...
# 4846  https://cdn.worldweatheronline.com/images/wsym...                Cloudy
# 4847  https://cdn.worldweatheronline.com/images/wsym...         Partly cloudy
# 4848  https://cdn.worldweatheronline.com/images/wsym...              Overcast
# 4849  https://cdn.worldweatheronline.com/images/wsym...                Cloudy
# 4850  https://cdn.worldweatheronline.com/images/wsym...              Overcast
#
#       ...  DewPointF  WindChillC  WindChillF  WindGustMiles  WindGustKmph  \
# 0     ...         67          23          74              8            14
# 1     ...         62          23          73             11            18
# 2     ...         61          24          75             15            25
# 3     ...         68          22          71              4             7
# 4     ...         69          23          73              5             8
# ...   ...        ...         ...         ...            ...           ...
# 4846  ...         58          21          69              6            10
# 4847  ...         58          22          72              6            10
# 4848  ...         56          19          66             16            26
# 4849  ...         55          19          67             13            21
# 4850  ...         62          20          68             15            25
#
#       FeelsLikeC  FeelsLikeF  uvIndex   sunrise    sunset
# 0             25          77        5  05:28 AM  08:30 PM
# 1             24          75        6  05:28 AM  08:30 PM
# 2             25          76        6  05:29 AM  08:30 PM
# 3             22          71        5  05:30 AM  08:29 PM
# 4             24          75        6  05:30 AM  08:29 PM
# ...          ...         ...      ...       ...       ...
# 4846          21          69        5  06:58 AM  06:27 PM
# 4847          23          73        6  06:59 AM  06:25 PM
# 4848          19          66        4  07:00 AM  06:23 PM
# 4849          19          67        4  07:01 AM  06:22 PM
# 4850          20          68        5  07:02 AM  06:20 PM
#
# [4851 rows x 29 columns]

# %%
weather.drop(['weatherCode',
              'weatherIconUrl',
              'WindChillC',
              'WindGustKmph',
              'sunrise',
              'sunset'], axis = 1, inplace = True)

# %%
weather
# Out:
#             date  maxtempF  mintempF  avgtempF  totalprecipIn  windspeedMiles  \
# 0     2008-07-01        80        67        74           0.14               5
# 1     2008-07-02        81        66        73           0.02               7
# 2     2008-07-03        83        67        75           0.00               9
# 3     2008-07-04        76        69        71           0.24               3
# 4     2008-07-05        79        68        73           0.50               3
# ...          ...       ...       ...       ...            ...             ...
# 4846  2021-10-07        74        65        69           0.00               5
# 4847  2021-10-08        83        66        72           0.00               5
# 4848  2021-10-09        69        64        66           0.01              13
# 4849  2021-10-10        70        64        67           0.00              10
# 4850  2021-10-11        74        64        68           0.00              12
#
#      winddir16point           weatherDesc  humidity  visibilityKm  ...  \
# 0               SSW  Patchy rain possible        80             9  ...
# 1                 W                 Sunny        70            10  ...
# 2                SW                 Sunny        64            10  ...
# 3               SSW     Light rain shower        88             9  ...
# 4                SE                 Sunny        86             8  ...
# ...             ...                   ...       ...           ...  ...
# 4846             SW                Cloudy        68            10  ...
# 4847            WSW         Partly cloudy        63            10  ...
# 4848              E              Overcast        69            10  ...
# 4849              E                Cloudy        65            10  ...
# 4850             NE              Overcast        82            10  ...
#
#       cloudcover  HeatIndexC  HeatIndexF  DewPointC  DewPointF  WindChillF  \
# 0             15          25          77         19         67          74
# 1             17          24          75         17         62          73
# 2              7          25          76         16         61          75
# 3             45          24          76         20         68          71
# 4             33          24          75         20         69          73
# ...          ...         ...         ...        ...        ...         ...
# 4846          62          21          70         14         58          69
# 4847          23          23          73         15         58          72
# 4848          90          19          66         13         56          66
# 4849          81          20          67         13         55          67
# 4850          83          21          70         17         62          68
#
#       WindGustMiles  FeelsLikeC  FeelsLikeF  uvIndex
# 0                 8          25          77        5
# 1                11          24          75        6
# 2                15          25          76        6
# 3                 4          22          71        5
# 4                 5          24          75        6
# ...             ...         ...         ...      ...
# 4846              6          21          69        5
# 4847              6          23          73        6
# 4848             16          19          66        4
# 4849             13          19          67        4
# 4850             15          20          68        5
#
# [4851 rows x 23 columns]

# %%
weather.drop(['HeatIndexC',
              'DewPointC',
              'FeelsLikeC',
              'visibilityKm'], axis = 1, inplace = True)

# %%
weather
# Out:
#             date  maxtempF  mintempF  avgtempF  totalprecipIn  windspeedMiles  \
# 0     2008-07-01        80        67        74           0.14               5
# 1     2008-07-02        81        66        73           0.02               7
# 2     2008-07-03        83        67        75           0.00               9
# 3     2008-07-04        76        69        71           0.24               3
# 4     2008-07-05        79        68        73           0.50               3
# ...          ...       ...       ...       ...            ...             ...
# 4846  2021-10-07        74        65        69           0.00               5
# 4847  2021-10-08        83        66        72           0.00               5
# 4848  2021-10-09        69        64        66           0.01              13
# 4849  2021-10-10        70        64        67           0.00              10
# 4850  2021-10-11        74        64        68           0.00              12
#
#      winddir16point           weatherDesc  humidity  visibilityMiles  \
# 0               SSW  Patchy rain possible        80                5
# 1                 W                 Sunny        70                6
# 2                SW                 Sunny        64                6
# 3               SSW     Light rain shower        88                5
# 4                SE                 Sunny        86                4
# ...             ...                   ...       ...              ...
# 4846             SW                Cloudy        68                6
# 4847            WSW         Partly cloudy        63                6
# 4848              E              Overcast        69                6
# 4849              E                Cloudy        65                6
# 4850             NE              Overcast        82                6
#
#       pressureMB  pressureInches  cloudcover  HeatIndexF  DewPointF  \
# 0           1011              30          15          77         67
# 1           1015              30          17          75         62
# 2           1015              30           7          76         61
# 3           1016              30          45          76         68
# 4           1016              30          33          75         69
# ...          ...             ...         ...         ...        ...
# 4846        1024              31          62          70         58
# 4847        1021              31          23          73         58
# 4848        1024              31          90          66         56
# 4849        1024              31          81          67         55
# 4850        1017              31          83          70         62
#
#       WindChillF  WindGustMiles  FeelsLikeF  uvIndex
# 0             74              8          77        5
# 1             73             11          75        6
# 2             75             15          76        6
# 3             71              4          71        5
# 4             73              5          75        6
# ...          ...            ...         ...      ...
# 4846          69              6          69        5
# 4847          72              6          73        6
# 4848          66             16          66        4
# 4849          67             13          67        4
# 4850          68             15          68        5
#
# [4851 rows x 19 columns]

# %%
weather['date'] = pd.to_datetime(weather['date'], utc=False)

# %%
weather.drop('FeelsLikeF', axis = 1, inplace = True)

# %%
weather.drop('pressureMB', axis = 1, inplace = True)

# %%
weather.drop('pressureInches', axis = 1, inplace = True)

# %%
weather.loc[0, 'date'].day_name()
# Out:
# 'Tuesday'

# %%
weather['date'].max()-weather['date'].min()
# Out:
# Timedelta('4850 days 00:00:00')

# %%
#standard deviation and mean of precipitation month by month
#standard deviation and mean of max/min/avg temp month by month 
#avg precipation for every month for every year (look at july 2010, july 2011, july 2012,...)
#standard deviation and mean of windspeed month by month
#is there a correlation between difference of WindGust and WindSpeed and amount of precipation

# %%
weather.set_index('date', inplace = True)

# %%
weather
# Out:
#             maxtempF  mintempF  avgtempF  totalprecipIn  windspeedMiles  \
# date
# 2008-07-01        80        67        74           0.14               5
# 2008-07-02        81        66        73           0.02               7
# 2008-07-03        83        67        75           0.00               9
# 2008-07-04        76        69        71           0.24               3
# 2008-07-05        79        68        73           0.50               3
# ...              ...       ...       ...            ...             ...
# 2021-10-07        74        65        69           0.00               5
# 2021-10-08        83        66        72           0.00               5
# 2021-10-09        69        64        66           0.01              13
# 2021-10-10        70        64        67           0.00              10
# 2021-10-11        74        64        68           0.00              12
#
#            winddir16point           weatherDesc  humidity  visibilityMiles  \
# date
# 2008-07-01            SSW  Patchy rain possible        80                5
# 2008-07-02              W                 Sunny        70                6
# 2008-07-03             SW                 Sunny        64                6
# 2008-07-04            SSW     Light rain shower        88                5
# 2008-07-05             SE                 Sunny        86                4
# ...                   ...                   ...       ...              ...
# 2021-10-07             SW                Cloudy        68                6
# 2021-10-08            WSW         Partly cloudy        63                6
# 2021-10-09              E              Overcast        69                6
# 2021-10-10              E                Cloudy        65                6
# 2021-10-11             NE              Overcast        82                6
#
#             pressureMB  pressureInches  cloudcover  HeatIndexF  DewPointF  \
# date
# 2008-07-01        1011              30          15          77         67
# 2008-07-02        1015              30          17          75         62
# 2008-07-03        1015              30           7          76         61
# 2008-07-04        1016              30          45          76         68
# 2008-07-05        1016              30          33          75         69
# ...                ...             ...         ...         ...        ...
# 2021-10-07        1024              31          62          70         58
# 2021-10-08        1021              31          23          73         58
# 2021-10-09        1024              31          90          66         56
# 2021-10-10        1024              31          81          67         55
# 2021-10-11        1017              31          83          70         62
#
#             WindChillF  WindGustMiles  uvIndex
# date
# 2008-07-01          74              8        5
# 2008-07-02          73             11        6
# 2008-07-03          75             15        6
# 2008-07-04          71              4        5
# 2008-07-05          73              5        6
# ...                ...            ...      ...
# 2021-10-07          69              6        5
# 2021-10-08          72              6        6
# 2021-10-09          66             16        4
# 2021-10-10          67             13        4
# 2021-10-11          68             15        5
#
# [4851 rows x 17 columns]

# %%
#getting monthly average of max temp from july 2008 to oct 2021
max_avg = weather['maxtempF'].resample('M').mean()
max_std = weather['maxtempF'].resample('M').std()

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
max_avg.plot()
max_std.plot()
plt.title('High Temp Monthly Avgs')
plt.ylabel('Temp (deg F)')
# Out:
# Text(0, 0.5, 'Temp (deg F)')

# %%
min_avg = weather['mintempF'].resample('M').mean()
min_std = weather['mintempF'].resample('M').std()

# %%
import datetime as datetime 
min_avg = pd.DataFrame(min_avg)
dates = pd.date_range(start = datetime.date(2008,7,31), periods=160, freq='M')
plt.scatter(x = dates, y = min_avg['mintempF'])
plt.ylim(0, 90)
# Out:
# (0.0, 90.0)

# %%
min_avg.plot(c = 'k')
min_std.plot(c = 'g')
plt.ylabel('Temp (deg F)')
# Out:
# Text(0, 0.5, 'Temp (deg F)')

# %%
precip_avg = weather['totalprecipIn'].resample('M').mean()
precip_std = weather['totalprecipIn'].resample('M').std()

# %%
precip_avg.plot(c='r', 
                label = 'monthly avg')
precip_std.plot(c='g',
                label = 'monthly std dev')
plt.title('Monthly Precipitation')
plt.legend()

# %%
yrpre_avg = weather['totalprecipIn'].resample('Y').mean()
yrpre_std = weather['totalprecipIn'].resample('Y').std()

# %%
windsp_avg = weather['windspeedMiles'].resample('M').mean()


windsp_std = weather['windspeedMiles'].resample('M').std()

# %%
import datetime as datetime 
plt.style.use('seaborn')

windsp_avg = pd.DataFrame(windsp_avg)
dates = pd.date_range(start = datetime.date(2008,7,31), periods=160, freq='M')
plt.scatter(x = np.array(dates), 
            y = np.array(windsp_avg['windspeedMiles']), 
            marker='.', 
            c='k', 
            label = 'average')


windsp_std = pd.DataFrame(windsp_std)
plt.scatter(x = np.array(dates), 
            y = np.array(windsp_std['windspeedMiles']), 
            marker='.', 
            c='r',
            label = 'std dev')
plt.legend()

# %%
rainy = weather.groupby(['weatherDesc'])

# %%
def sub(a,b):
    return a - b
weather['temp_range'] = weather.apply(lambda row: sub(row['maxtempF'], row['mintempF']), axis = 1)
col_temprange = weather.pop('temp_range')
weather.insert(2, 'temp_range', col_temprange)

weather['wind_range'] = weather.apply(lambda row: sub(row['WindGustMiles'], row['windspeedMiles']), axis = 1)
col_windrange = weather.pop('wind_range')
col_windgust = weather.pop('WindGustMiles')

weather.insert(5, 'WindGustMiles', col_windgust)
weather.insert(7, 'wind_range', col_windrange)

# %%
weather

#sum of rain inches of every year and see how that changes over time
#is there a correlation between wind direction and precipitation?
#sum of snow inches for every winter season and see how that changes over time
# Out:
#             maxtempF  mintempF  temp_range  avgtempF  totalprecipIn  \
# date
# 2008-07-01        80        67          13        74           0.14
# 2008-07-02        81        66          15        73           0.02
# 2008-07-03        83        67          16        75           0.00
# 2008-07-04        76        69           7        71           0.24
# 2008-07-05        79        68          11        73           0.50
# ...              ...       ...         ...       ...            ...
# 2021-10-07        74        65           9        69           0.00
# 2021-10-08        83        66          17        72           0.00
# 2021-10-09        69        64           5        66           0.01
# 2021-10-10        70        64           6        67           0.00
# 2021-10-11        74        64          10        68           0.00
#
#             WindGustMiles  windspeedMiles  wind_range winddir16point  \
# date
# 2008-07-01              8               5           3            SSW
# 2008-07-02             11               7           4              W
# 2008-07-03             15               9           6             SW
# 2008-07-04              4               3           1            SSW
# 2008-07-05              5               3           2             SE
# ...                   ...             ...         ...            ...
# 2021-10-07              6               5           1             SW
# 2021-10-08              6               5           1            WSW
# 2021-10-09             16              13           3              E
# 2021-10-10             13              10           3              E
# 2021-10-11             15              12           3             NE
#
#                      weatherDesc  humidity  visibilityMiles  cloudcover  \
# date
# 2008-07-01  Patchy rain possible        80                5          15
# 2008-07-02                 Sunny        70                6          17
# 2008-07-03                 Sunny        64                6           7
# 2008-07-04     Light rain shower        88                5          45
# 2008-07-05                 Sunny        86                4          33
# ...                          ...       ...              ...         ...
# 2021-10-07                Cloudy        68                6          62
# 2021-10-08         Partly cloudy        63                6          23
# 2021-10-09              Overcast        69                6          90
# 2021-10-10                Cloudy        65                6          81
# 2021-10-11              Overcast        82                6          83
#
#             HeatIndexF  DewPointF  WindChillF  uvIndex
# date
# 2008-07-01          77         67          74        5
# 2008-07-02          75         62          73        6
# 2008-07-03          76         61          75        6
# 2008-07-04          76         68          71        5
# 2008-07-05          75         69          73        6
# ...                ...        ...         ...      ...
# 2021-10-07          70         58          69        5
# 2021-10-08          73         58          72        6
# 2021-10-09          66         56          66        4
# 2021-10-10          67         55          67        4
# 2021-10-11          70         62          68        5
#
# [4851 rows x 17 columns]

# %%
weather.reset_index()['date']
# Out:
# 0      2008-07-01
# 1      2008-07-02
# 2      2008-07-03
# 3      2008-07-04
# 4      2008-07-05
#           ...
# 4846   2021-10-07
# 4847   2021-10-08
# 4848   2021-10-09
# 4849   2021-10-10
# 4850   2021-10-11
# Name: date, Length: 4851, dtype: datetime64[ns]

# %%
plt.scatter(weather['temp_range'], weather['totalprecipIn'],
            c ="red",
            s = 10)
plt.style.use('seaborn')
plt.ylabel('precipitation (in)')
plt.xlabel('Temperature Difference (deg F)')
plt.title('Daily Temperature Difference vs Total Precipitation')
# Out:
# Text(0.5, 1.0, 'Daily Temperature Difference vs Total Precipitation')

# %%
plt.scatter(weather['windspeedMiles'], weather['totalprecipIn'], 
            c ="brown", 
            s = 8)

# %%
weather['weatherDesc'].unique()
# Out:
# array(['Patchy rain possible', 'Sunny', 'Light rain shower',
#        'Partly cloudy', 'Moderate or heavy rain shower',
#        'Patchy light rain with thunder', 'Heavy rain', 'Light drizzle',
#        'Fog', 'Light rain', 'Cloudy', 'Mist', 'Overcast', 'Moderate rain',
#        'Patchy light drizzle', 'Heavy snow', 'Blizzard', 'Moderate snow',
#        'Patchy moderate snow', 'Patchy light rain',
#        'Torrential rain shower', 'Patchy heavy snow', 'Light snow',
#        'Moderate or heavy snow showers', 'Blowing snow',
#        'Patchy light snow', 'Patchy snow possible', 'Light sleet',
#        'Thundery outbreaks possible', 'Moderate rain at times',
#        'Moderate or heavy sleet', 'Ice pellets',
#        'Patchy freezing drizzle possible', 'Heavy rain at times',
#        'Moderate or heavy rain with thunder'], dtype=object)

# %%
import re
extract = weather['weatherDesc']
extract
# Out:
# date
# 2008-07-01             rain
# 2008-07-02            Sunny
# 2008-07-03            Sunny
# 2008-07-04             rain
# 2008-07-05            Sunny
#                   ...
# 2021-10-07           Cloudy
# 2021-10-08    Partly cloudy
# 2021-10-09         Overcast
# 2021-10-10           Cloudy
# 2021-10-11         Overcast
# Name: weatherDesc, Length: 4851, dtype: object

# %%
extract = extract.apply(lambda s: 'snow' if 'snow' in s 
                                         or 'Blizzard' in s 
                                         or 'Ice' in s 
                                                else s)
extract_rain = extract.apply(lambda x: 'rain' if 'rain' in x 
                                              or 'drizzle' in x 
                                              or 'sleet' in x 
                                                 else x)

# %%
weather['weatherDesc'] = extract
weather['weatherDesc'].unique()
# Out:
# array(['rain', 'Sunny', 'Partly cloudy', 'Light drizzle', 'Fog', 'Cloudy',
#        'Mist', 'Overcast', 'Patchy light drizzle', 'snow',
#        'Thundery outbreaks possible', 'Patchy freezing drizzle possible'],
#       dtype=object)

# %%
weather['weatherDesc'] = extract_rain

# %%
weather['weatherDesc'].unique()
# Out:
# array(['rain', 'Sunny', 'Partly cloudy', 'Fog', 'Cloudy', 'Mist',
#        'Overcast', 'snow', 'Thundery outbreaks possible'], dtype=object)

# %%
weather
# Out:
#            date  maxtempF  mintempF  temp_range  avgtempF  totalprecipIn  \
# 0    2008-07-01        80        67          13        74           0.14
# 1    2008-07-02        81        66          15        73           0.02
# 2    2008-07-03        83        67          16        75           0.00
# 3    2008-07-04        76        69           7        71           0.24
# 4    2008-07-05        79        68          11        73           0.50
# ...         ...       ...       ...         ...       ...            ...
# 4846 2021-10-07        74        65           9        69           0.00
# 4847 2021-10-08        83        66          17        72           0.00
# 4848 2021-10-09        69        64           5        66           0.01
# 4849 2021-10-10        70        64           6        67           0.00
# 4850 2021-10-11        74        64          10        68           0.00
#
#       WindGustMiles  windspeedMiles  wind_range winddir16point    weatherDesc  \
# 0                 8               5           3            SSW           rain
# 1                11               7           4              W          Sunny
# 2                15               9           6             SW          Sunny
# 3                 4               3           1            SSW           rain
# 4                 5               3           2             SE          Sunny
# ...             ...             ...         ...            ...            ...
# 4846              6               5           1             SW         Cloudy
# 4847              6               5           1            WSW  Partly cloudy
# 4848             16              13           3              E       Overcast
# 4849             13              10           3              E         Cloudy
# 4850             15              12           3             NE       Overcast
#
#       humidity  visibilityMiles  cloudcover  HeatIndexF  DewPointF  \
# 0           80                5          15          77         67
# 1           70                6          17          75         62
# 2           64                6           7          76         61
# 3           88                5          45          76         68
# 4           86                4          33          75         69
# ...        ...              ...         ...         ...        ...
# 4846        68                6          62          70         58
# 4847        63                6          23          73         58
# 4848        69                6          90          66         56
# 4849        65                6          81          67         55
# 4850        82                6          83          70         62
#
#       WindChillF  uvIndex
# 0             74        5
# 1             73        6
# 2             75        6
# 3             71        5
# 4             73        6
# ...          ...      ...
# 4846          69        5
# 4847          72        6
# 4848          66        4
# 4849          67        4
# 4850          68        5
#
# [4851 rows x 18 columns]

# %%
weather['weatherDesc'].value_counts()
# Out:
# Sunny                          2291
# Partly cloudy                  1088
# rain                            884
# Overcast                        240
# Cloudy                          203
# snow                            120
# Mist                             18
# Thundery outbreaks possible       5
# Fog                               2
# Name: weatherDesc, dtype: int64

# %%
weather.reset_index(inplace = True)

# %%
weather['date']
# Out:
# 0      2008-07-01
# 1      2008-07-02
# 2      2008-07-03
# 3      2008-07-04
# 4      2008-07-05
#           ...
# 4846   2021-10-07
# 4847   2021-10-08
# 4848   2021-10-09
# 4849   2021-10-10
# 4850   2021-10-11
# Name: date, Length: 4851, dtype: datetime64[ns]

# %%
per = weather.date.dt.to_period("M")
per2 = weather.date.dt.to_period("Y")
monthly_precip = weather.groupby(per)['totalprecipIn'].agg('sum')
yearly_precip = weather.groupby(per2)['totalprecipIn'].agg('sum')
plt.style.use('seaborn')
plt.title('Monthly and Yearly Total Precipitation')
monthly_precip.plot(label = 'Monthly Total')
yearly_precip.plot(label = 'Yearly Total')
plt.xlim('2010', '2020')
plt.ylim(0, 100)
plt.xlabel('Year')
plt.ylabel('Precipitation (in)')
plt.legend()

# %%
monthly_precip2 = weather.groupby(per)['totalprecipIn'].agg('mean')
yearly_precip2 = weather.groupby(per2)['totalprecipIn'].agg('mean')
plt.style.use('seaborn')
plt.title('Monthly and Yearly Average Precipitation')
monthly_precip2.plot(c='y', label = 'Monthly Average')
yearly_precip2.plot(c='k', label = 'Yearly Average')
plt.xlim('2009','2020')
plt.ylim(0 , 1)
plt.xlabel('Year')
plt.ylabel('Precipitation (in)')
plt.legend()

# %%
monthly_precip2 = weather.groupby(per)['totalprecipIn'].agg('mean')[5:139]
yearly_precip2 = weather.groupby(per2)['totalprecipIn'].agg('mean')[1:13]
monthly_precip2.plot(c='m', label = 'monthly std dev')
yearly_precip2.plot(c='k', label = 'yearly std dev')

plt.legend()

# %%
weather
# Out:
#            date  maxtempF  mintempF  temp_range  avgtempF  totalprecipIn  \
# 0    2008-07-01        80        67          13        74           0.14
# 1    2008-07-02        81        66          15        73           0.02
# 2    2008-07-03        83        67          16        75           0.00
# 3    2008-07-04        76        69           7        71           0.24
# 4    2008-07-05        79        68          11        73           0.50
# ...         ...       ...       ...         ...       ...            ...
# 4846 2021-10-07        74        65           9        69           0.00
# 4847 2021-10-08        83        66          17        72           0.00
# 4848 2021-10-09        69        64           5        66           0.01
# 4849 2021-10-10        70        64           6        67           0.00
# 4850 2021-10-11        74        64          10        68           0.00
#
#       WindGustMiles  windspeedMiles  wind_range winddir16point    weatherDesc  \
# 0                 8               5           3            SSW           rain
# 1                11               7           4              W          Sunny
# 2                15               9           6             SW          Sunny
# 3                 4               3           1            SSW           rain
# 4                 5               3           2             SE          Sunny
# ...             ...             ...         ...            ...            ...
# 4846              6               5           1             SW         Cloudy
# 4847              6               5           1            WSW  Partly cloudy
# 4848             16              13           3              E       Overcast
# 4849             13              10           3              E         Cloudy
# 4850             15              12           3             NE       Overcast
#
#       humidity  visibilityMiles  cloudcover  HeatIndexF  DewPointF  \
# 0           80                5          15          77         67
# 1           70                6          17          75         62
# 2           64                6           7          76         61
# 3           88                5          45          76         68
# 4           86                4          33          75         69
# ...        ...              ...         ...         ...        ...
# 4846        68                6          62          70         58
# 4847        63                6          23          73         58
# 4848        69                6          90          66         56
# 4849        65                6          81          67         55
# 4850        82                6          83          70         62
#
#       WindChillF  uvIndex
# 0             74        5
# 1             73        6
# 2             75        6
# 3             71        5
# 4             73        6
# ...          ...      ...
# 4846          69        5
# 4847          72        6
# 4848          66        4
# 4849          67        4
# 4850          68        5
#
# [4851 rows x 18 columns]

# %%
filt = weather['weatherDesc'] == 'rain'
filt2 = weather['weatherDesc'] == 'snow'

# %%
rain = weather.loc[filt]
snow = weather.loc[filt2]

# %%
rain.date.dt.month
snow.date.dt.month
rain = pd.DataFrame(rain)
snow = pd.DataFrame(snow)
# Out:
# 0        7
# 3        7
# 21       7
# 22       7
# 26       7
#         ..
# 4825     9
# 4831     9
# 4832     9
# 4843    10
# 4844    10
# Name: date, Length: 884, dtype: int64

# %%
rain['Year'] = rain.date.dt.year
snow['Year'] = snow.date.dt.year
rain
# Out:
#            date  maxtempF  mintempF  temp_range  avgtempF  totalprecipIn  \
# 0    2008-07-01        80        67          13        74           0.14
# 3    2008-07-04        76        69           7        71           0.24
# 21   2008-07-22        83        72          11        76           0.44
# 22   2008-07-23        82        72          10        76           0.39
# 26   2008-07-27        80        69          11        74           0.50
# ...         ...       ...       ...         ...       ...            ...
# 4825 2021-09-16        73        70           3        72           0.18
# 4831 2021-09-22        79        72           7        75           0.03
# 4832 2021-09-23        73        64           9        69           0.15
# 4843 2021-10-04        81        69          12        74           0.09
# 4844 2021-10-05        67        65           2        66           0.07
#
#       WindGustMiles  windspeedMiles  wind_range winddir16point weatherDesc  \
# 0                 8               5           3            SSW        rain
# 3                 4               3           1            SSW        rain
# 21                7               5           2              E        rain
# 22               12               9           3            ESE        rain
# 26               11               7           4            SSW        rain
# ...             ...             ...         ...            ...         ...
# 4825             10               7           3            ESE        rain
# 4831             17              13           4             SE        rain
# 4832             17              12           5            SSW        rain
# 4843              8               6           2            SSW        rain
# 4844             11               8           3            ENE        rain
#
#       humidity  visibilityMiles  cloudcover  HeatIndexF  DewPointF  \
# 0           80                5          15          77         67
# 3           88                5          45          76         68
# 21          86                5          32          81         72
# 22          86                5          36          81         71
# 26          87                5          35          77         70
# ...        ...              ...         ...         ...        ...
# 4825        89                4          77          76         68
# 4831        75                6          79          79         66
# 4832        81                6          76          71         63
# 4843        72                6          75          77         64
# 4844        90                6          99          66         63
#
#       WindChillF  uvIndex  Year
# 0             74        5  2008
# 3             71        5  2008
# 21            76        5  2008
# 22            76        5  2008
# 26            74        5  2008
# ...          ...      ...   ...
# 4825          72        5  2021
# 4831          75        5  2021
# 4832          69        5  2021
# 4843          74        5  2021
# 4844          66        4  2021
#
# [884 rows x 19 columns]

# %%
snow
# Out:
#            date  maxtempF  mintempF  temp_range  avgtempF  totalprecipIn  \
# 172  2008-12-20        31        24           7        26           0.22
# 183  2008-12-31        38        19          19        29           0.17
# 193  2009-01-10        32        25           7        28           0.34
# 198  2009-01-15        23        17           6        20           0.07
# 201  2009-01-18        33        22          11        29           0.15
# ...         ...       ...       ...         ...       ...            ...
# 4604 2021-02-07        33        30           3        32           0.67
# 4606 2021-02-09        33        24           9        29           0.44
# 4615 2021-02-18        28        23           5        26           0.75
# 4641 2021-03-16        35        26           9        32           0.19
# 4644 2021-03-19        46        31          15        37           0.72
#
#       WindGustMiles  windspeedMiles  wind_range winddir16point weatherDesc  \
# 172              18              13           5            NNE        snow
# 183              24              17           7            SSW        snow
# 193              11               8           3            SSE        snow
# 198              14              10           4              S        snow
# 201               6               4           2              S        snow
# ...             ...             ...         ...            ...         ...
# 4604             12               8           4             SE        snow
# 4606              6               4           2            SSW        snow
# 4615             12               9           3            ESE        snow
# 4641              8               6           2              E        snow
# 4644             24              19           5            ENE        snow
#
#       humidity  visibilityMiles  cloudcover  HeatIndexF  DewPointF  \
# 172         94                2         100          26         24
# 183         76                4          65          29         22
# 193         77                4          66          28         21
# 198         71                3          75          20         12
# 201         82                2          82          29         24
# ...        ...              ...         ...         ...        ...
# 4604        82                3          90          32         26
# 4606        93                3          83          29         27
# 4615        82                2          98          28         22
# 4641        48                4          68          33         13
# 4644        67                3          80          37         26
#
#       WindChillF  uvIndex  Year
# 172           14        1  2008
# 183           17        1  2008
# 193           20        1  2009
# 198            9        1  2009
# 201           23        1  2009
# ...          ...      ...   ...
# 4604          25        1  2021
# 4606          25        1  2021
# 4615          20        1  2021
# 4641          27        1  2021
# 4644          26        1  2021
#
# [120 rows x 19 columns]

# %%
#counting the number of times it rained & snowed per year
rain_num = rain.Year.value_counts().sort_index()[1:14]
snow_num = snow.Year.value_counts().sort_index()[1:14]

rain_num.plot(kind = 'bar', label = 'Rain', color = '#0000ff')
snow_num.plot(kind = 'bar', label = 'Snow', color = '#b4b4b4')
plt.title('Number of Rain and Snow Days')
plt.ylabel('Number of Days')
plt.xlabel('Year')
plt.legend()

# %%
#finding total number of inches of rain and snow per year
rain.groupby('Year').totalprecipIn.sum()
# Out:
# Year
# 2008    23.16
# 2009    48.35
# 2010    45.65
# 2011    65.02
# 2012    42.46
# 2013    49.26
# 2014    42.16
# 2015    37.97
# 2016    44.74
# 2017    50.17
# 2018    61.41
# 2019    47.12
# 2020    41.83
# 2021    28.27
# Name: totalprecipIn, dtype: float64

# %%
snow.groupby('Year').totalprecipIn.sum()
# Out:
# Year
# 2008    0.39
# 2009    4.54
# 2010    4.58
# 2011    4.06
# 2012    1.00
# 2013    2.80
# 2014    4.37
# 2015    5.42
# 2016    4.75
# 2017    2.54
# 2018    5.30
# 2019    1.91
# 2020    0.41
# 2021    3.80
# Name: totalprecipIn, dtype: float64
